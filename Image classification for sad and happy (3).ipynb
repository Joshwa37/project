# %% [markdown]
# Import the Libraries

# %%
import tensorflow as tf
from pathlib import Path
import cv2
from PIL import Image
import os
import shutil
import matplotlib.pyplot as plt

# %% [markdown]
# Give the required GPU space for tensorflow

# %%
gpus=tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# %%
gpus
# Out:
# []

# %% [markdown]
# Data_dir is the collection of Happy and Sad images
# datad is the folder used to store the filtered images

# %%
data_dir='datacat'
image_exts=['jpeg','png','jpg']
datad='filterimagecat'

# %% [markdown]
# filter from the correpted images

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir,image_class)):
        image_path=os.path.join(data_dir,image_class,image)
        if '.ipynb_checkpoints' not in image_path:
            img=cv2.imread(image_path)
            img1=Image.open(image_path)
            tip=img1.format.lower()
            if tip in image_exts:
                source=Path(f'{data_dir}/{image_class}/{image}')
                destination=Path(f'{datad}/{image_class}/{image}')
                shutil.copy(source,destination)
data_dir='filterimage'

# %%
data_dir='filterimagecat'

# %%
imgg=cv2.imread(os.path.join(data_dir,'Cat','1.png'))
print(imgg)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[195 193 194]
#   [197 195 195]
#   [198 196 196]
#   ...
#   [132 120 120]
#   [135 123 123]
#   [130 118 118]]
#
#  [[193 190 191]
#   [195 193 193]
#   [197 195 195]
#   ...
#   [133 121 121]
#   [134 122 122]
#   [129 117 117]]
#
#  [[187 185 185]
#   [190 188 188]
#   [192 190 190]
#   ...
#   [131 119 119]
#   [130 118 118]
#   [126 114 114]]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=tf.keras.utils.image_dataset_from_directory('filterimagecat',batch_size=20,image_size=(128,128))
# Out:
# Found 384 files belonging to 2 classes.

# %%
data_iterator=data.as_numpy_iterator()
batch=data_iterator.next()

# %%
data=data.map(lambda x,y:(x/255,y))
scaled_iterator=data.as_numpy_iterator()
batch=scaled_iterator.next()
batch[0].max()
# Out:
# 1.0

# %%
len(data)
# Out:
# 20

# %%
train_size=int(len(data)*.5)
val_size=int(len(data)*.2)+1
test_size=int(len(data)*.1)+1

# %%
train_size+val_size+test_size
# Out:
# 18

# %%
train=data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %%
len(train)
# Out:
# 10

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

# %%
model=Sequential()

# %%
model.add(Conv2D(16,(3,3),1,activation='relu'))
print("done")
model.add(MaxPooling2D())

model.add(Conv2D(32,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(14400))

model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
print("done")
# Out:
# done
# done

# %%
model.compile('adam',loss=tf.losses.BinaryCrossentropy(),metrics=['accuracy'])

# %%
logdir='logs'

# %%
tensorboard_callback=tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train,epochs=20,validation_data=val)
# Out:
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 603ms/step - accuracy: 0.5369 - loss: 1.3358 - val_accuracy: 0.6100 - val_loss: 0.6546
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 566ms/step - accuracy: 0.6296 - loss: 0.6134 - val_accuracy: 0.6400 - val_loss: 0.6261
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 553ms/step - accuracy: 0.7586 - loss: 0.5826 - val_accuracy: 0.6700 - val_loss: 0.6276
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 544ms/step - accuracy: 0.7896 - loss: 0.4741 - val_accuracy: 0.7400 - val_loss: 0.5480
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 544ms/step - accuracy: 0.8909 - loss: 0.3691 - val_accuracy: 0.8500 - val_loss: 0.4547
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 568ms/step - accuracy: 0.8750 - loss: 0.3554 - val_accuracy: 0.8300 - val_loss: 0.4386
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 632ms/step - accuracy: 0.9315 - loss: 0.2055 - val_accuracy: 0.7900 - val_loss: 0.4716
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 583ms/step - accuracy: 0.9025 - loss: 0.2490 - val_accuracy: 0.8300 - val_loss: 0.4540
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 522ms/step - accuracy: 0.9004 - loss: 0.2707 - val_accuracy: 0.8300 - val_loss: 0.3878
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 527ms/step - accuracy: 0.8913 - loss: 0.2319 - val_accuracy: 0.8000 - val_loss: 0.6485
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 536ms/step - accuracy: 0.8700 - loss: 0.3779 - val_accuracy: 0.8000 - val_loss: 0.5041
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 537ms/step - accuracy: 0.9030 - loss: 0.2383 - val_accuracy: 0.8300 - val_loss: 0.4948
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 513ms/step - accuracy: 0.9291 - loss: 0.1538 - val_accuracy: 0.8900 - val_loss: 0.3849
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 522ms/step - accuracy: 0.9508 - loss: 0.1280 - val_accuracy: 0.8400 - val_loss: 0.4883
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 551ms/step - accuracy: 0.9354 - loss: 0.1416 - val_accuracy: 0.8300 - val_loss: 0.4852
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 528ms/step - accuracy: 0.9374 - loss: 0.1826 - val_accuracy: 0.8100 - val_loss: 0.5967
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 549ms/step - accuracy: 0.9398 - loss: 0.2047 - val_accuracy: 0.8600 - val_loss: 0.3403
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 586ms/step - accuracy: 0.9486 - loss: 0.1354 - val_accuracy: 0.9000 - val_loss: 0.4291
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 629ms/step - accuracy: 0.9326 - loss: 0.1346 - val_accuracy: 0.9100 - val_loss: 0.3619
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 734ms/step - accuracy: 0.9960 - loss: 0.0311 - val_accuracy: 0.8800 - val_loss: 0.5372

# %%
fig=plt.figure()
plt.plot(hist.history['loss'],color='teal',label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val_loss')
fig.suptitle('Loss',fontsize=20)
plt.legend(loc="upper left")
plt. show()

# %%
fig=plt.figure()
plt.plot(hist.history['accuracy'],color='teal',label='accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='val_accuracy')
fig.suptitle('accuracy',fontsize=20)
plt.legend(loc="upper left")
plt. show()

# %%
from tensorflow.keras.metrics import Precision,Recall,BinaryAccuracy

# %%
pre=Precision()
re=Recall()
acc=BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    X,y=batch
    yhat=model.predict(X)
    pre.update_state(y,yhat)
    re.update_state(y,yhat)
    acc.update_state(y,yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step

# %%
print(pre.result().numpy())
print(re.result().numpy())
print(acc.result().numpy())
# Out:
# 0.8235294
# 0.9032258
# 0.85

# %%
import cv2

# %%
img=cv2.imread('2.png')
plt.imshow(img)
plt.show()

# %%
resize=tf.image.resize(img,(128,128))

# %%
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
np.expand_dims(resize,0)
# Out:
# array([[[[ 89.77734   , 196.51172   , 153.51172   ],
#          [100.06641   , 199.44644   , 157.44644   ],
#          [ 93.546875  , 189.2963    , 151.07422   ],
#          ...,
#          [ 34.08261   , 156.97598   , 110.995514  ],
#          [ 21.88507   , 159.9559    , 112.        ],
#          [ 11.970428  , 163.41574   , 113.08984   ]],
#
#         [[ 87.29019   , 185.98047   , 143.98047   ],
#          [ 93.19922   , 186.13672   , 145.13672   ],
#          [ 91.02301   , 180.09116   , 143.28473   ],
#          ...,
#          [ 47.83203   , 155.19489   , 112.12674   ],
#          [ 26.522919  , 153.        , 106.33203   ],
#          [  0.46762085, 151.25      , 100.55972   ]],
#
#         [[ 78.33594   , 177.5586    , 135.5586    ],
#          [ 79.67578   , 172.78732   , 131.78732   ],
#          [ 78.53226   , 166.64554   , 126.64554   ],
#          ...,
#          [ 51.961945  , 155.03717   , 115.47467   ],
#          [ 42.983063  , 151.9961    , 112.880646  ],
#          [ 31.99942   , 149.76953   , 114.64844   ]],
#
#         ...,
#
#         [[  0.        ,  90.671875  ,  60.89453   ],
#          [ 65.505646  , 141.06207   ,  89.73395   ],
#          [ 49.230713  , 139.90637   , 109.30191   ],
#          ...,
#          [108.07687   , 106.094635  , 131.01248   ],
#          [ 92.193146  ,  84.53299   , 111.65234   ],
#          [105.47165   ,  96.47946   , 129.374     ]],
#
#         [[  2.7355042 , 102.87109   ,  70.244965  ],
#          [ 24.627869  ,  97.29584   ,  53.43698   ],
#          [ 71.74393   , 153.74393   , 117.19098   ],
#          ...,
#          [149.93362   , 156.72226   , 186.47269   ],
#          [130.0393    , 133.63748   , 164.36847   ],
#          [140.27838   , 141.67682   , 178.69635   ]],
#
#         [[ 19.494415  , 111.38504   ,  78.3616    ],
#          [ 26.046875  ,  95.64844   ,  72.84149   ],
#          [ 59.089417  , 156.7092    , 132.29904   ],
#          ...,
#          [118.985535  , 195.02069   , 170.7879    ],
#          [176.04749   , 193.29184   , 202.80078   ],
#          [191.91406   , 196.69641   , 219.3482    ]]]], dtype=float32)

# %%
yhat=model.predict(np.expand_dims(resize/255,0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step

# %%
yhat
# Out:
# array([[1.1643057e-06]], dtype=float32)

# %%
if yhat>=0.5:
    print('Given image is dog')
else:
    print('Given image is cat')
# Out:
# Given image is cat
